# %% [markdown]
# # CIFAR Classification
#
# ### Exercise objectives
#
# - Implement a CNN for a 10-class classification problem
# - Enhance the CNN performance with data augmentation techniques
# - Experiment the acceleration of GPU for image processing (Google Colab)
#
# <hr>
# <hr>
#
# You should now have a better feeling of how a CNN is working, and especially how the convolutions are affecting the image to detect specific features. Therefore, let's now play with a bit more complex images.
#
# The CIFAR-10 dataset is a dataset that contains images of 10 different classes
#
# <img src="https://people.minesparis.psl.eu/fabien.moutarde/ES_MachineLearning/mini-projets/cifar10_notebook_fichiers/cifar_10.png">
#
# This dataset is emblematic in the research community as many enhancements for image problems have been achieved on this dataset, and later on the CIFAR-100 dataset once the performance got too high. You can check the [wikipedia](https://en.wikipedia.org/wiki/CIFAR-10) page of the dataset if you want to know more about it.
#
# In this notebook, we propose to implement a CNN to distinguish the 10 categories from the CIFAR-10 dataset. Again, remember that until 10 years ago, this problem was very challenging to the entire research community and is now for you to tackle.

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %% [markdown]
# ## 0. Colab
#
# **First, make sure to use GPU acceleration** by clicking on `"Runtime --> Change runtime --> GPU"` if you are on Colab.

# %% [markdown]
# ## 1. Data
#
# We'll take care of data loading and preprocessing for you. Just run the following cells and make sure you understand them

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np

(images_train, labels_train), (images_test, labels_test) = cifar10.load_data()
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 5000,
#  1: 5000,
#  2: 5000,
#  3: 5000,
#  4: 5000,
#  5: 5000,
#  6: 5000,
#  7: 5000,
#  8: 5000,
#  9: 5000}

# %% [markdown]
# ❗️ 50,000 images may take a long time to train: **Always start with a subsample to iterate quickly** before scaling up
#
# Below, we divide the dataset size by `reduction_factor=10`. Don't try to increase it unless we ask you too.

# %%
# Reduce size
reduction_factor = 10

idx_train =  np.random.choice(len(images_train), round(len(images_train)/reduction_factor))
idx_test =  np.random.choice(len(images_test), round(len(images_test)/reduction_factor))

images_train_small = images_train[idx_train]
images_test_small = images_test[idx_test]
labels_train_small = labels_train[idx_train]
labels_test_small = labels_test[idx_test]

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train_small, return_counts=True)
dict(zip(unique, counts))
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 446,
#  1: 505,
#  2: 507,
#  3: 484,
#  4: 517,
#  5: 524,
#  6: 492,
#  7: 493,
#  8: 500,
#  9: 532}

# %%
# Let's plot few images to see what they look like
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
for i in range(6):
    plt.subplot(1,6, i+1)
    img = images_train[i]
    label = labels_train[i][0]
    plt.imshow(img)
    plt.title(labels[label])

# %% [markdown]
# And, as usual,
# - we normalize the data between 0 and 1
# - we create `y` as one-hot-encoded version of `labels`

# %%
X_train = images_train / 255.
X_train_small = images_train_small / 255.
X_test = images_test / 255.
X_test_small = images_test_small / 255.

from tensorflow.keras.utils import to_categorical
y_train = to_categorical(labels_train, 10)
y_train_small = to_categorical(labels_train_small, 10)
y_test = to_categorical(labels_test, 10)
y_test_small = to_categorical(labels_test_small, 10)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %% [markdown]
# ## 2. Iterate on your CNN architecture using your small training set
#
#
# ❓ **Question** ❓ Your turn to shine!
#
# - Define the CNN architecture of your choice in a method `initialize_model()`
# - Compile your model in a method `compile_model()`:
# - Fit it on your **small** training set **only**
# - Store the output of the fit in an `history` variable
# - Try a first model yourself, before looking at PRO TIPS below
#
# <details>
#     <summary> 🆘 PRO TIPS 🆘  </summary>
#
#
# - Do not forget to add the input shape of your data to the first layer: it has 3 colors
# - Start simple, complexify after few trials to get better results
# - The task is complex: Try at least 3 or 4 convolutions
# - Kernel size do not need to be large for such small picture resolution!
# - Add some Maxpooling (but not too much else the activation "image" will become too small)
# - Keep padding = 'same' and 'stride' = (1,1) to start with.
# - Once your model overfits, try adding some dropout layer to regularize the network. A good tip is too increase dropout strengh as you move closer to the output, so as not to overfit on your end-result
# - Images are so small, that you can use larger batch size (32 or 64) to benefit from even more GPU parallelization
# </details>

# %%
def initialize_model():
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    # YOUR CODE HERE
    model = models.Sequential()
    ### First convolution & max-pooling
    model.add(layers.Conv2D(8, kernel_size=(4,4), input_shape= (32, 32, 3), activation = 'relu', padding='same'))
    # To complete
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    
    ### Second convolution & max-pooling
    model.add(layers.Conv2D(16, kernel_size=(3,3), activation = 'relu', padding='same'))
    # To complete
    model.add(layers.MaxPool2D(pool_size=(2,2)))

    ### Flattening
    model.add(layers.Flatten())
    # To complete

    ### One fully connected
    model.add(layers.Dense(10, activation = 'relu'))
    # To complete

    ### Last layer (let's say a classification with 10 output)
    model.add(layers.Dense(10, activation = 'softmax'))
    # To complete
  
    return model

# %%
model = initialize_model()

# %%
def compile_model(model):
    '''return a compiled model suited for the cifar tasks'''
    # YOUR CODE HERE
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer= 'adam')
    return model

# %%
model = compile_model(model)

# %%
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience=10, restore_best_weights=True)
    
history = model.fit(X_train_small, y_train_small, batch_size=32, epochs=100, validation_split=0.3, callbacks=[es], verbose=1)
model.summary()
# Out:
# Epoch 1/100
# 110/110 [==============================] - 1s 7ms/step - loss: 2.3000 - accuracy: 0.0949 - val_loss: 2.2950 - val_accuracy: 0.1060
# Epoch 2/100
# 110/110 [==============================] - 1s 5ms/step - loss: 2.2943 - accuracy: 0.1140 - val_loss: 2.2711 - val_accuracy: 0.1760
# Epoch 3/100
# 110/110 [==============================] - 1s 5ms/step - loss: 2.1754 - accuracy: 0.1643 - val_loss: 2.0918 - val_accuracy: 0.2213
# Epoch 4/100
# 110/110 [==============================] - 1s 5ms/step - loss: 2.0393 - accuracy: 0.2231 - val_loss: 2.0357 - val_accuracy: 0.2180
# Epoch 5/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.9314 - accuracy: 0.2609 - val_loss: 1.9220 - val_accuracy: 0.2513
# Epoch 6/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.8483 - accuracy: 0.3034 - val_loss: 1.8269 - val_accuracy: 0.3080
# Epoch 7/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.7809 - accuracy: 0.3266 - val_loss: 1.7589 - val_accuracy: 0.3387
# Epoch 8/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.6966 - accuracy: 0.3431 - val_loss: 1.7318 - val_accuracy: 0.3320
# Epoch 9/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.6780 - accuracy: 0.3431 - val_loss: 1.7538 - val_accuracy: 0.3160
# Epoch 10/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.6409 - accuracy: 0.3623 - val_loss: 1.6788 - val_accuracy: 0.3400
# Epoch 11/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5801 - accuracy: 0.3831 - val_loss: 1.6917 - val_accuracy: 0.3347
# Epoch 12/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5409 - accuracy: 0.3974 - val_loss: 1.6710 - val_accuracy: 0.3547
# Epoch 13/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5302 - accuracy: 0.3977 - val_loss: 1.6918 - val_accuracy: 0.3520
# Epoch 14/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5125 - accuracy: 0.4100 - val_loss: 1.6316 - val_accuracy: 0.3607
# Epoch 15/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4819 - accuracy: 0.4246 - val_loss: 1.6005 - val_accuracy: 0.3700
# Epoch 16/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4634 - accuracy: 0.4317 - val_loss: 1.6245 - val_accuracy: 0.3673
# Epoch 17/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4602 - accuracy: 0.4306 - val_loss: 1.6045 - val_accuracy: 0.3673
# Epoch 18/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4251 - accuracy: 0.4394 - val_loss: 1.5907 - val_accuracy: 0.3720
# Epoch 19/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4180 - accuracy: 0.4446 - val_loss: 1.6001 - val_accuracy: 0.3720
# Epoch 20/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3895 - accuracy: 0.4634 - val_loss: 1.6086 - val_accuracy: 0.3647
# Epoch 21/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3786 - accuracy: 0.4566 - val_loss: 1.6245 - val_accuracy: 0.3700
# Epoch 22/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3623 - accuracy: 0.4651 - val_loss: 1.6360 - val_accuracy: 0.3833
# Epoch 23/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3437 - accuracy: 0.4711 - val_loss: 1.6410 - val_accuracy: 0.3813
# Epoch 24/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3375 - accuracy: 0.4737 - val_loss: 1.6059 - val_accuracy: 0.3753
# Epoch 25/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3218 - accuracy: 0.4891 - val_loss: 1.6332 - val_accuracy: 0.3733
# Epoch 26/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3118 - accuracy: 0.4837 - val_loss: 1.6394 - val_accuracy: 0.3727
# Epoch 27/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2823 - accuracy: 0.4949 - val_loss: 1.6262 - val_accuracy: 0.3767
# Epoch 28/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2841 - accuracy: 0.4940 - val_loss: 1.6779 - val_accuracy: 0.3680
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 32, 32, 8)         392
#
#  max_pooling2d_11 (MaxPoolin  (None, 16, 16, 8)        0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 16)        1168
#
#  max_pooling2d_12 (MaxPoolin  (None, 8, 8, 16)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 10)                10250
#
#  dense_9 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 11,920
# Trainable params: 11,920
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ❓ **Question** ❓ Run the following function on the previous history (keep the default arguments, these are intended for future plots in the notebook).

# %%
def plot_history(history, title='', axs=None, exp_name=""):
    if axs is not None:
        ax1, ax2 = axs
    else:
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    
    if len(exp_name) > 0 and exp_name[0] != '_':
        exp_name = '_' + exp_name
    ax1.plot(history.history['loss'], label='train' + exp_name)
    ax1.plot(history.history['val_loss'], label='val' + exp_name)
    ax1.set_ylim(0., 2.2)
    ax1.set_title('loss')
    ax1.legend()

    ax2.plot(history.history['accuracy'], label='train accuracy'  + exp_name)
    ax2.plot(history.history['val_accuracy'], label='val accuracy'  + exp_name)
    ax2.set_ylim(0.25, 1.)
    ax2.set_title('Accuracy')
    ax2.legend()
    return (ax1, ax2)

# %%
plot_history(history, title='', axs=None, exp_name="")
# L'objectif de cette étape est d'avoir unune bonne accuracy sur les données de validation. 
# On trvaillera ensuite l'overfitting dans une deuxième étape en effaçant certaines données.
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f3d74ce8190>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3d74b5b880>)

# %% [markdown]
# ❓ **Question** ❓ Evaluate your model on the test data and compare it with baseline. Are you satisfied with these performances ? Look at PRO TIPS above and iterate a bit if you want to improve!

# %% [markdown]
# Keep padding = 'same' and 'stride' = (1,1) to start with.
# Once your model overfits, try adding some dropout layer to regularize the network. A good tip is too increase dropout strengh as you move closer to the output, so as not to overfit on your end-result
#
# Images are so small, that you can use larger batch size (32 or 64) to benefit from even more GPU parallelization

# %%
# YOUR CODE HERE
def initialize_model_2():
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    # YOUR CODE HERE
    model = models.Sequential()
    
    ### First convolution & max-pooling
    model.add(layers.Conv2D(32, kernel_size=(3,3), input_shape= (32,32 , 3), activation = 'relu', padding='same'))
    # To complete
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    # couche de suppression
    model.add(layers.Dropout(0.25))
    
    ### Second convolution & max-pooling
    model.add(layers.Conv2D(64, kernel_size=(3,3), activation = 'relu', padding='same'))
    # To complete
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    # couche de suppression
    model.add(layers.Dropout(0.5))

    ### Third convolution & max-pooling
    model.add(layers.Conv2D(128, kernel_size=(4,4), activation = 'relu', padding='same'))
    # To complete
    model.add(layers.MaxPool2D(pool_size=(4,4)))
    # couche de suppression
    model.add(layers.Dropout(0.75))

    ### Flattening
    model.add(layers.Flatten())
   
    ### One fully connected
    model.add(layers.Dense(10, activation = 'relu'))

    ### Last layer (let's say a classification with 10 output)
    model.add(layers.Dense(10, activation = 'softmax'))
    # To complete
  
    return model

# %%
model = initialize_model_2()
model = compile_model(model)

# %%
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience=10, restore_best_weights=True)
    
history = model.fit(X_train_small, y_train_small, batch_size=32, epochs=100, validation_split=0.3, callbacks=[es], verbose=1)
model.summary()
# Out:
# Epoch 1/100
# 110/110 [==============================] - 1s 8ms/step - loss: 2.3069 - accuracy: 0.1026 - val_loss: 2.2894 - val_accuracy: 0.1253
# Epoch 2/100
# 110/110 [==============================] - 1s 6ms/step - loss: 2.2371 - accuracy: 0.1583 - val_loss: 2.1978 - val_accuracy: 0.1633
# Epoch 3/100
# 110/110 [==============================] - 1s 6ms/step - loss: 2.1416 - accuracy: 0.1829 - val_loss: 2.0915 - val_accuracy: 0.2253
# Epoch 4/100
# 110/110 [==============================] - 1s 6ms/step - loss: 2.0613 - accuracy: 0.2229 - val_loss: 2.0394 - val_accuracy: 0.2547
# Epoch 5/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.9893 - accuracy: 0.2400 - val_loss: 1.9374 - val_accuracy: 0.2920
# Epoch 6/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.9114 - accuracy: 0.2843 - val_loss: 1.8893 - val_accuracy: 0.2840
# Epoch 7/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.8822 - accuracy: 0.2817 - val_loss: 1.8040 - val_accuracy: 0.3320
# Epoch 8/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.8457 - accuracy: 0.2963 - val_loss: 1.7843 - val_accuracy: 0.3147
# Epoch 9/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.8068 - accuracy: 0.3040 - val_loss: 1.7633 - val_accuracy: 0.3660
# Epoch 10/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.7836 - accuracy: 0.3157 - val_loss: 1.7544 - val_accuracy: 0.3627
# Epoch 11/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.7494 - accuracy: 0.3283 - val_loss: 1.6841 - val_accuracy: 0.3800
# Epoch 12/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.7434 - accuracy: 0.3369 - val_loss: 1.6957 - val_accuracy: 0.3800
# Epoch 13/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.7033 - accuracy: 0.3543 - val_loss: 1.6645 - val_accuracy: 0.3880
# Epoch 14/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.6700 - accuracy: 0.3620 - val_loss: 1.6286 - val_accuracy: 0.3873
# Epoch 15/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.6672 - accuracy: 0.3657 - val_loss: 1.6316 - val_accuracy: 0.4100
# Epoch 16/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.6316 - accuracy: 0.3889 - val_loss: 1.6178 - val_accuracy: 0.4173
# Epoch 17/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.6078 - accuracy: 0.3920 - val_loss: 1.5888 - val_accuracy: 0.4247
# Epoch 18/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.6027 - accuracy: 0.3986 - val_loss: 1.5573 - val_accuracy: 0.4420
# Epoch 19/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5747 - accuracy: 0.4037 - val_loss: 1.5200 - val_accuracy: 0.4560
# Epoch 20/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5729 - accuracy: 0.4051 - val_loss: 1.5693 - val_accuracy: 0.4287
# Epoch 21/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.5549 - accuracy: 0.4200 - val_loss: 1.5043 - val_accuracy: 0.4633
# Epoch 22/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5358 - accuracy: 0.4283 - val_loss: 1.4909 - val_accuracy: 0.4607
# Epoch 23/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.5097 - accuracy: 0.4411 - val_loss: 1.5290 - val_accuracy: 0.4607
# Epoch 24/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4951 - accuracy: 0.4406 - val_loss: 1.4567 - val_accuracy: 0.4693
# Epoch 25/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4774 - accuracy: 0.4449 - val_loss: 1.4397 - val_accuracy: 0.4893
# Epoch 26/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4821 - accuracy: 0.4457 - val_loss: 1.4395 - val_accuracy: 0.4813
# Epoch 27/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4657 - accuracy: 0.4514 - val_loss: 1.4139 - val_accuracy: 0.4940
# Epoch 28/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.4365 - accuracy: 0.4660 - val_loss: 1.4127 - val_accuracy: 0.4920
# Epoch 29/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4528 - accuracy: 0.4671 - val_loss: 1.4212 - val_accuracy: 0.4813
# Epoch 30/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.4256 - accuracy: 0.4757 - val_loss: 1.3794 - val_accuracy: 0.5033
# Epoch 31/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4095 - accuracy: 0.4749 - val_loss: 1.3759 - val_accuracy: 0.5167
# Epoch 32/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4062 - accuracy: 0.4820 - val_loss: 1.3710 - val_accuracy: 0.5033
# Epoch 33/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4071 - accuracy: 0.4757 - val_loss: 1.3783 - val_accuracy: 0.4987
# Epoch 34/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.3974 - accuracy: 0.4691 - val_loss: 1.3769 - val_accuracy: 0.5013
# Epoch 35/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.3558 - accuracy: 0.4931 - val_loss: 1.3469 - val_accuracy: 0.5147
# Epoch 36/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.3434 - accuracy: 0.4989 - val_loss: 1.3395 - val_accuracy: 0.5180
# Epoch 37/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.3723 - accuracy: 0.4920 - val_loss: 1.3724 - val_accuracy: 0.5147
# Epoch 38/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3503 - accuracy: 0.5020 - val_loss: 1.3222 - val_accuracy: 0.5273
# Epoch 39/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3646 - accuracy: 0.5011 - val_loss: 1.3758 - val_accuracy: 0.4953
# Epoch 40/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.3381 - accuracy: 0.5049 - val_loss: 1.3174 - val_accuracy: 0.5333
# Epoch 41/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3186 - accuracy: 0.5114 - val_loss: 1.3209 - val_accuracy: 0.5287
# Epoch 42/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.3237 - accuracy: 0.5117 - val_loss: 1.3138 - val_accuracy: 0.5213
# Epoch 43/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3044 - accuracy: 0.5194 - val_loss: 1.3222 - val_accuracy: 0.5220
# Epoch 44/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.3010 - accuracy: 0.5146 - val_loss: 1.3205 - val_accuracy: 0.5407
# Epoch 45/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.3002 - accuracy: 0.5140 - val_loss: 1.2723 - val_accuracy: 0.5400
# Epoch 46/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.2729 - accuracy: 0.5274 - val_loss: 1.2772 - val_accuracy: 0.5613
# Epoch 47/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.2773 - accuracy: 0.5289 - val_loss: 1.3043 - val_accuracy: 0.5273
# Epoch 48/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3009 - accuracy: 0.5114 - val_loss: 1.2877 - val_accuracy: 0.5267
# Epoch 49/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2746 - accuracy: 0.5286 - val_loss: 1.2827 - val_accuracy: 0.5453
# Epoch 50/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.2549 - accuracy: 0.5271 - val_loss: 1.2764 - val_accuracy: 0.5460
# Epoch 51/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.2489 - accuracy: 0.5340 - val_loss: 1.2677 - val_accuracy: 0.5460
# Epoch 52/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2674 - accuracy: 0.5266 - val_loss: 1.2940 - val_accuracy: 0.5420
# Epoch 53/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.2523 - accuracy: 0.5323 - val_loss: 1.2568 - val_accuracy: 0.5607
# Epoch 54/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2486 - accuracy: 0.5369 - val_loss: 1.2133 - val_accuracy: 0.5653
# Epoch 55/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.2394 - accuracy: 0.5331 - val_loss: 1.2414 - val_accuracy: 0.5607
# Epoch 56/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2410 - accuracy: 0.5497 - val_loss: 1.2618 - val_accuracy: 0.5513
# Epoch 57/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2238 - accuracy: 0.5346 - val_loss: 1.2359 - val_accuracy: 0.5600
# Epoch 58/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.2265 - accuracy: 0.5474 - val_loss: 1.2452 - val_accuracy: 0.5620
# Epoch 59/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.2055 - accuracy: 0.5500 - val_loss: 1.2492 - val_accuracy: 0.5413
# Epoch 60/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.2430 - accuracy: 0.5309 - val_loss: 1.2512 - val_accuracy: 0.5487
# Epoch 61/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.1967 - accuracy: 0.5577 - val_loss: 1.2171 - val_accuracy: 0.5720
# Epoch 62/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.1860 - accuracy: 0.5514 - val_loss: 1.2684 - val_accuracy: 0.5513
# Epoch 63/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2067 - accuracy: 0.5571 - val_loss: 1.2382 - val_accuracy: 0.5693
# Epoch 64/100
# 110/110 [==============================] - 1s 6ms/step - loss: 1.1909 - accuracy: 0.5617 - val_loss: 1.2387 - val_accuracy: 0.5680
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_14 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 128)         131200
#
#  max_pooling2d_15 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 2, 2, 128)         0
#
#  flatten_5 (Flatten)         (None, 512)               0
#
#  dense_10 (Dense)            (None, 10)                5130
#
#  dense_11 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 155,832
# Trainable params: 155,832
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_history(history, title='', axs=None, exp_name="")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f3d74bce280>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3d7496a970>)

# %% [markdown]
# ## 3. Increase data size

# %% [markdown]
# ❓ **Question** ❓ Now that your model fits on a small subsample, try to fit it on the full dataset and notice how performance increases.
#
# 🚨 **Make sure to use GPU acceleration** by clicking on `"Runtime --> Change runtime --> GPU"` if you are on Colab.
#
# 💡 Training neural network on images (in each batch) can be parallelized, and this parallelization procedure can be done on GPU.

# %%
# YOUR CODE HERE
es = EarlyStopping(patience=10, restore_best_weights=True)
    
history = model.fit(X_train, y_train, batch_size=32, epochs=100, validation_split=0.3, callbacks=[es], verbose=1)
model.summary()
# Out:
# Epoch 1/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.4253 - accuracy: 0.4812 - val_loss: 1.2773 - val_accuracy: 0.5527
# Epoch 2/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.3730 - accuracy: 0.4966 - val_loss: 1.2919 - val_accuracy: 0.5483
# Epoch 3/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.3465 - accuracy: 0.5083 - val_loss: 1.2116 - val_accuracy: 0.5921
# Epoch 4/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.3188 - accuracy: 0.5167 - val_loss: 1.2100 - val_accuracy: 0.5795
# Epoch 5/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.2957 - accuracy: 0.5281 - val_loss: 1.1857 - val_accuracy: 0.5867
# Epoch 6/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.2833 - accuracy: 0.5316 - val_loss: 1.1408 - val_accuracy: 0.6194
# Epoch 7/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.2635 - accuracy: 0.5409 - val_loss: 1.1825 - val_accuracy: 0.6081
# Epoch 8/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.2487 - accuracy: 0.5456 - val_loss: 1.1575 - val_accuracy: 0.6023
# Epoch 9/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.2287 - accuracy: 0.5549 - val_loss: 1.1048 - val_accuracy: 0.6327
# Epoch 10/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.2128 - accuracy: 0.5601 - val_loss: 1.1459 - val_accuracy: 0.6011
# Epoch 11/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.2060 - accuracy: 0.5660 - val_loss: 1.0940 - val_accuracy: 0.6354
# Epoch 12/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1938 - accuracy: 0.5694 - val_loss: 1.0372 - val_accuracy: 0.6560
# Epoch 13/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1859 - accuracy: 0.5757 - val_loss: 1.0395 - val_accuracy: 0.6379
# Epoch 14/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1845 - accuracy: 0.5731 - val_loss: 1.0614 - val_accuracy: 0.6350
# Epoch 15/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1705 - accuracy: 0.5794 - val_loss: 1.0461 - val_accuracy: 0.6451
# Epoch 16/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1601 - accuracy: 0.5836 - val_loss: 1.0237 - val_accuracy: 0.6536
# Epoch 17/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1523 - accuracy: 0.5834 - val_loss: 1.0350 - val_accuracy: 0.6382
# Epoch 18/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1396 - accuracy: 0.5914 - val_loss: 1.0448 - val_accuracy: 0.6528
# Epoch 19/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1352 - accuracy: 0.5908 - val_loss: 1.0260 - val_accuracy: 0.6505
# Epoch 20/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1391 - accuracy: 0.5918 - val_loss: 1.0101 - val_accuracy: 0.6601
# Epoch 21/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1293 - accuracy: 0.5927 - val_loss: 1.0076 - val_accuracy: 0.6567
# Epoch 22/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1197 - accuracy: 0.6014 - val_loss: 0.9753 - val_accuracy: 0.6759
# Epoch 23/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1157 - accuracy: 0.6015 - val_loss: 0.9622 - val_accuracy: 0.6743
# Epoch 24/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1217 - accuracy: 0.5982 - val_loss: 0.9909 - val_accuracy: 0.6695
# Epoch 25/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1105 - accuracy: 0.6021 - val_loss: 0.9744 - val_accuracy: 0.6715
# Epoch 26/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1034 - accuracy: 0.6040 - val_loss: 1.0110 - val_accuracy: 0.6479
# Epoch 27/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0985 - accuracy: 0.6074 - val_loss: 0.9403 - val_accuracy: 0.6835
# Epoch 28/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0982 - accuracy: 0.6083 - val_loss: 0.9377 - val_accuracy: 0.6891
# Epoch 29/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0942 - accuracy: 0.6087 - val_loss: 0.9536 - val_accuracy: 0.6788
# Epoch 30/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0917 - accuracy: 0.6114 - val_loss: 0.9446 - val_accuracy: 0.6994
# Epoch 31/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0797 - accuracy: 0.6154 - val_loss: 0.9853 - val_accuracy: 0.6653
# Epoch 32/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0744 - accuracy: 0.6187 - val_loss: 0.9325 - val_accuracy: 0.6963
# Epoch 33/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0776 - accuracy: 0.6167 - val_loss: 0.9365 - val_accuracy: 0.6780
# Epoch 34/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0714 - accuracy: 0.6171 - val_loss: 0.8963 - val_accuracy: 0.7027
# Epoch 35/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0707 - accuracy: 0.6172 - val_loss: 0.9493 - val_accuracy: 0.6921
# Epoch 36/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0570 - accuracy: 0.6219 - val_loss: 0.9296 - val_accuracy: 0.6865
# Epoch 37/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0580 - accuracy: 0.6232 - val_loss: 0.8868 - val_accuracy: 0.7037
# Epoch 38/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0548 - accuracy: 0.6253 - val_loss: 0.9086 - val_accuracy: 0.6948
# Epoch 39/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0565 - accuracy: 0.6213 - val_loss: 0.8884 - val_accuracy: 0.7012
# Epoch 40/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0472 - accuracy: 0.6276 - val_loss: 0.9087 - val_accuracy: 0.7045
# Epoch 41/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0482 - accuracy: 0.6268 - val_loss: 0.8799 - val_accuracy: 0.7129
# Epoch 42/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0436 - accuracy: 0.6271 - val_loss: 0.8895 - val_accuracy: 0.7136
# Epoch 43/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0461 - accuracy: 0.6291 - val_loss: 0.8878 - val_accuracy: 0.7188
# Epoch 44/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0498 - accuracy: 0.6275 - val_loss: 0.9359 - val_accuracy: 0.6975
# Epoch 45/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0427 - accuracy: 0.6300 - val_loss: 0.9054 - val_accuracy: 0.7069
# Epoch 46/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0405 - accuracy: 0.6307 - val_loss: 0.8811 - val_accuracy: 0.7045
# Epoch 47/100
# 1094/1094 [==============================] - 6s 6ms/step - loss: 1.0321 - accuracy: 0.6363 - val_loss: 0.8875 - val_accuracy: 0.7055
# Epoch 48/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 1.0351 - accuracy: 0.6344 - val_loss: 0.8624 - val_accuracy: 0.7165
# Epoch 49/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0272 - accuracy: 0.6333 - val_loss: 0.9100 - val_accuracy: 0.6953
# Epoch 50/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0339 - accuracy: 0.6334 - val_loss: 0.8630 - val_accuracy: 0.7165
# Epoch 51/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0280 - accuracy: 0.6344 - val_loss: 0.8553 - val_accuracy: 0.7249
# Epoch 52/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0194 - accuracy: 0.6396 - val_loss: 0.8737 - val_accuracy: 0.7023
# Epoch 53/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0184 - accuracy: 0.6397 - val_loss: 0.8690 - val_accuracy: 0.7165
# Epoch 54/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0188 - accuracy: 0.6404 - val_loss: 0.8905 - val_accuracy: 0.7043
# Epoch 55/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0226 - accuracy: 0.6371 - val_loss: 0.8952 - val_accuracy: 0.7033
# Epoch 56/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0151 - accuracy: 0.6390 - val_loss: 0.8441 - val_accuracy: 0.7220
# Epoch 57/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0186 - accuracy: 0.6384 - val_loss: 0.8706 - val_accuracy: 0.7185
# Epoch 58/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0093 - accuracy: 0.6400 - val_loss: 0.8828 - val_accuracy: 0.7062
# Epoch 59/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0130 - accuracy: 0.6427 - val_loss: 0.8519 - val_accuracy: 0.7212
# Epoch 60/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0134 - accuracy: 0.6435 - val_loss: 0.8948 - val_accuracy: 0.6959
# Epoch 61/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0038 - accuracy: 0.6462 - val_loss: 0.8409 - val_accuracy: 0.7165
# Epoch 62/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0038 - accuracy: 0.6447 - val_loss: 0.8498 - val_accuracy: 0.7266
# Epoch 63/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0018 - accuracy: 0.6439 - val_loss: 0.8325 - val_accuracy: 0.7193
# Epoch 64/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0017 - accuracy: 0.6453 - val_loss: 0.8712 - val_accuracy: 0.7088
# Epoch 65/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9950 - accuracy: 0.6464 - val_loss: 0.8353 - val_accuracy: 0.7191
# Epoch 66/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9967 - accuracy: 0.6465 - val_loss: 0.8741 - val_accuracy: 0.7095
# Epoch 67/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9992 - accuracy: 0.6459 - val_loss: 0.8657 - val_accuracy: 0.7115
# Epoch 68/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9955 - accuracy: 0.6480 - val_loss: 0.8535 - val_accuracy: 0.7167
# Epoch 69/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9995 - accuracy: 0.6479 - val_loss: 0.8514 - val_accuracy: 0.7129
# Epoch 70/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9928 - accuracy: 0.6497 - val_loss: 0.8368 - val_accuracy: 0.7146
# Epoch 71/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9959 - accuracy: 0.6441 - val_loss: 0.8720 - val_accuracy: 0.7077
# Epoch 72/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9965 - accuracy: 0.6498 - val_loss: 0.8333 - val_accuracy: 0.7301
# Epoch 73/100
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9883 - accuracy: 0.6529 - val_loss: 0.8375 - val_accuracy: 0.7265
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_14 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 128)         131200
#
#  max_pooling2d_15 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 2, 2, 128)         0
#
#  flatten_5 (Flatten)         (None, 512)               0
#
#  dense_10 (Dense)            (None, 10)                5130
#
#  dense_11 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 155,832
# Trainable params: 155,832
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_history(history, title='', axs=None, exp_name="")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f3d7a430b50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3d7a430610>)

# %% [markdown]
# ## 4. Data augmentation
#
# ☝️ It seems that adding pictures greatly improves model performance! Welcome to the Deep Learning paradigm, where big data does make a difference.
#
# To easily improve the accuracy of a model without much work, we can generate new data: the _data augmentation_. This widely used technique consists in applying little transformation to input images without changing its label, as mirroring, cropping, intensity changes, etc. The improved performance simply results from the Neural network training with more different data.
#
# The natural way to generate these new images is to apply some transformations and train the model on the original and new images. However, such procedure requires to keep all these images in memory : it can be very intensive, to the point that your computer memory cannot hold any new image (your computer might even crash).
#
# For this reason, we will augment the data **on the fly** (batch per batch), meaning that we will create new data, use them to fit the model, then delete them. Here, Keras is our friend as it provides the utils to do all this job for us. Look at the following code : the general writing can seem odd but don't be panicked: just look at the function arguments that defines the augmentation techniques that we will use and that you can check in the  [documentation](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator).

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=(0.8, 1.2),
    ) 

datagen.fit(X_train)
datagen

# %%
X_augmented_iterator = datagen.flow(X_train, shuffle=False, batch_size=1)
X_augmented_iterator

# %% [markdown]
# 💡 Always visualize your data augmentation in order to double check that you can still recognize the label yourself!

# %%
import numpy as np

for i, (raw_image, augmented_image) in enumerate(zip(X_train, X_augmented_iterator)):
    _, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 2))
    ax1.imshow(raw_image)
    ax2.imshow(augmented_image[0])
    plt.show()
    
    if i > 10:
        break

# %% [markdown]
# ❗ **Remark** ❗ In this example, there is one augmented image per initial image. In fact, when your model will use `datagen.flow` in the `fit`, it will create one augmentation per epochs! Indeed, the images in the original dataset will not be provided to the optimizer, only augmented ones instead. (But because the augmentations are performed randomly, this allows both modified images and some very close of the originals).
#
# ❓ **Question** ❓ Take time to understand the cell below: Previously, we used the `validation_split` argument to let the model separate a training set from the validation one. It is not possible here as **using an image in the training set and its transformation in the validation set is considered as a data leakage**. Therefore, we have to manually define the `validation_data` with the following commands:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# The model
model_aug = initialize_model_2()
model_aug = compile_model(model_aug)

# The data generator
X_tr = X_train[:40000]
y_tr = y_train[:40000]
X_val = X_train[40000:]
y_val = y_train[40000:]
train_flow = datagen.flow(X_tr, y_tr, batch_size=64)

# The early stopping criterion
es = EarlyStopping(patience=15)

# The fit
history_aug = model_aug.fit(train_flow, 
                        epochs=70, 
                        callbacks=[es], 
                        validation_data=(X_val, y_val))
# Out:
# Epoch 1/70
# 625/625 [==============================] - 22s 34ms/step - loss: 2.0745 - accuracy: 0.2095 - val_loss: 1.8067 - val_accuracy: 0.3481
# Epoch 2/70
# 625/625 [==============================] - 23s 37ms/step - loss: 1.7943 - accuracy: 0.3316 - val_loss: 1.5800 - val_accuracy: 0.4404
# Epoch 3/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.6492 - accuracy: 0.3892 - val_loss: 1.4782 - val_accuracy: 0.4630
# Epoch 4/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.5799 - accuracy: 0.4198 - val_loss: 1.4048 - val_accuracy: 0.5025
# Epoch 5/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.5364 - accuracy: 0.4362 - val_loss: 1.3540 - val_accuracy: 0.5325
# Epoch 6/70
# 625/625 [==============================] - 20s 32ms/step - loss: 1.5007 - accuracy: 0.4491 - val_loss: 1.3112 - val_accuracy: 0.5321
# Epoch 7/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.4770 - accuracy: 0.4592 - val_loss: 1.3288 - val_accuracy: 0.5354
# Epoch 8/70
# 625/625 [==============================] - 20s 33ms/step - loss: 1.4596 - accuracy: 0.4702 - val_loss: 1.3069 - val_accuracy: 0.5364
# Epoch 9/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.4397 - accuracy: 0.4770 - val_loss: 1.3418 - val_accuracy: 0.5136
# Epoch 10/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.4199 - accuracy: 0.4855 - val_loss: 1.2804 - val_accuracy: 0.5511
# Epoch 11/70
# 625/625 [==============================] - 22s 34ms/step - loss: 1.4102 - accuracy: 0.4896 - val_loss: 1.2065 - val_accuracy: 0.5777
# Epoch 12/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.3959 - accuracy: 0.4942 - val_loss: 1.2123 - val_accuracy: 0.5711
# Epoch 13/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.3861 - accuracy: 0.5008 - val_loss: 1.1750 - val_accuracy: 0.5866
# Epoch 14/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.3811 - accuracy: 0.5019 - val_loss: 1.2003 - val_accuracy: 0.5843
# Epoch 15/70
# 625/625 [==============================] - 23s 37ms/step - loss: 1.3718 - accuracy: 0.5062 - val_loss: 1.1639 - val_accuracy: 0.5999
# Epoch 16/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.3592 - accuracy: 0.5109 - val_loss: 1.1938 - val_accuracy: 0.5915
# Epoch 17/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.3586 - accuracy: 0.5091 - val_loss: 1.2159 - val_accuracy: 0.5724
# Epoch 18/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.3490 - accuracy: 0.5148 - val_loss: 1.1831 - val_accuracy: 0.5940
# Epoch 19/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.3376 - accuracy: 0.5199 - val_loss: 1.1314 - val_accuracy: 0.6041
# Epoch 20/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.3235 - accuracy: 0.5237 - val_loss: 1.1596 - val_accuracy: 0.5940
# Epoch 21/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.3235 - accuracy: 0.5264 - val_loss: 1.1247 - val_accuracy: 0.6189
# Epoch 22/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.3181 - accuracy: 0.5257 - val_loss: 1.1160 - val_accuracy: 0.6191
# Epoch 23/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.3088 - accuracy: 0.5296 - val_loss: 1.1204 - val_accuracy: 0.6030
# Epoch 24/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.3041 - accuracy: 0.5306 - val_loss: 1.0921 - val_accuracy: 0.6217
# Epoch 25/70
# 625/625 [==============================] - 20s 33ms/step - loss: 1.3041 - accuracy: 0.5332 - val_loss: 1.0759 - val_accuracy: 0.6373
# Epoch 26/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2904 - accuracy: 0.5386 - val_loss: 1.0816 - val_accuracy: 0.6403
# Epoch 27/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2915 - accuracy: 0.5360 - val_loss: 1.0320 - val_accuracy: 0.6497
# Epoch 28/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2803 - accuracy: 0.5397 - val_loss: 1.0317 - val_accuracy: 0.6435
# Epoch 29/70
# 625/625 [==============================] - 23s 36ms/step - loss: 1.2722 - accuracy: 0.5409 - val_loss: 1.0932 - val_accuracy: 0.6176
# Epoch 30/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2758 - accuracy: 0.5418 - val_loss: 1.0976 - val_accuracy: 0.6129
# Epoch 31/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2775 - accuracy: 0.5433 - val_loss: 1.1122 - val_accuracy: 0.6031
# Epoch 32/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2676 - accuracy: 0.5449 - val_loss: 1.1164 - val_accuracy: 0.6038
# Epoch 33/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2613 - accuracy: 0.5478 - val_loss: 1.0771 - val_accuracy: 0.6317
# Epoch 34/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2534 - accuracy: 0.5512 - val_loss: 1.0491 - val_accuracy: 0.6489
# Epoch 35/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2572 - accuracy: 0.5513 - val_loss: 1.0503 - val_accuracy: 0.6429
# Epoch 36/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2457 - accuracy: 0.5570 - val_loss: 1.0146 - val_accuracy: 0.6591
# Epoch 37/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2504 - accuracy: 0.5538 - val_loss: 1.0203 - val_accuracy: 0.6516
# Epoch 38/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2389 - accuracy: 0.5545 - val_loss: 1.0276 - val_accuracy: 0.6579
# Epoch 39/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2409 - accuracy: 0.5552 - val_loss: 1.0690 - val_accuracy: 0.6256
# Epoch 40/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2401 - accuracy: 0.5583 - val_loss: 1.0308 - val_accuracy: 0.6441
# Epoch 41/70
# 625/625 [==============================] - 20s 33ms/step - loss: 1.2283 - accuracy: 0.5622 - val_loss: 0.9694 - val_accuracy: 0.6720
# Epoch 42/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2314 - accuracy: 0.5589 - val_loss: 1.0566 - val_accuracy: 0.6317
# Epoch 43/70
# 625/625 [==============================] - 23s 36ms/step - loss: 1.2331 - accuracy: 0.5592 - val_loss: 1.0247 - val_accuracy: 0.6468
# Epoch 44/70
# 625/625 [==============================] - 20s 33ms/step - loss: 1.2306 - accuracy: 0.5579 - val_loss: 0.9935 - val_accuracy: 0.6599
# Epoch 45/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2239 - accuracy: 0.5617 - val_loss: 1.0012 - val_accuracy: 0.6549
# Epoch 46/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2231 - accuracy: 0.5618 - val_loss: 0.9870 - val_accuracy: 0.6613
# Epoch 47/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2190 - accuracy: 0.5663 - val_loss: 1.0100 - val_accuracy: 0.6547
# Epoch 48/70
# 625/625 [==============================] - 20s 33ms/step - loss: 1.2188 - accuracy: 0.5639 - val_loss: 0.9564 - val_accuracy: 0.6787
# Epoch 49/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2179 - accuracy: 0.5641 - val_loss: 0.9636 - val_accuracy: 0.6767
# Epoch 50/70
# 625/625 [==============================] - 20s 33ms/step - loss: 1.2135 - accuracy: 0.5672 - val_loss: 1.0632 - val_accuracy: 0.6292
# Epoch 51/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2077 - accuracy: 0.5672 - val_loss: 0.9909 - val_accuracy: 0.6546
# Epoch 52/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2061 - accuracy: 0.5698 - val_loss: 1.0655 - val_accuracy: 0.6184
# Epoch 53/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.2013 - accuracy: 0.5726 - val_loss: 0.9915 - val_accuracy: 0.6645
# Epoch 54/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.1995 - accuracy: 0.5728 - val_loss: 0.9815 - val_accuracy: 0.6572
# Epoch 55/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.2009 - accuracy: 0.5702 - val_loss: 1.0078 - val_accuracy: 0.6500
# Epoch 56/70
# 625/625 [==============================] - 22s 36ms/step - loss: 1.2018 - accuracy: 0.5734 - val_loss: 0.9674 - val_accuracy: 0.6780
# Epoch 57/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.1973 - accuracy: 0.5742 - val_loss: 1.0323 - val_accuracy: 0.6394
# Epoch 58/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.1923 - accuracy: 0.5742 - val_loss: 0.9476 - val_accuracy: 0.6762
# Epoch 59/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.1941 - accuracy: 0.5796 - val_loss: 1.0087 - val_accuracy: 0.6557
# Epoch 60/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.1930 - accuracy: 0.5738 - val_loss: 0.9474 - val_accuracy: 0.6784
# Epoch 61/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.1901 - accuracy: 0.5766 - val_loss: 1.0373 - val_accuracy: 0.6344
# Epoch 62/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.1894 - accuracy: 0.5763 - val_loss: 0.9656 - val_accuracy: 0.6712
# Epoch 63/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.1876 - accuracy: 0.5785 - val_loss: 0.9591 - val_accuracy: 0.6761
# Epoch 64/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.1816 - accuracy: 0.5788 - val_loss: 0.9698 - val_accuracy: 0.6647
# Epoch 65/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.1792 - accuracy: 0.5806 - val_loss: 0.9228 - val_accuracy: 0.6867
# Epoch 66/70
# 625/625 [==============================] - 21s 34ms/step - loss: 1.1763 - accuracy: 0.5814 - val_loss: 0.9550 - val_accuracy: 0.6745
# Epoch 67/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.1798 - accuracy: 0.5828 - val_loss: 0.8981 - val_accuracy: 0.6996
# Epoch 68/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.1783 - accuracy: 0.5806 - val_loss: 0.8926 - val_accuracy: 0.6996
# Epoch 69/70
# 625/625 [==============================] - 23s 36ms/step - loss: 1.1692 - accuracy: 0.5852 - val_loss: 0.9492 - val_accuracy: 0.6689
# Epoch 70/70
# 625/625 [==============================] - 21s 33ms/step - loss: 1.1738 - accuracy: 0.5833 - val_loss: 0.9360 - val_accuracy: 0.6829

# %% [markdown]
# ❗️❗️ Remark ❗️❗️: The training can be quite long here. Don't hesitate to go to the next exercise and gome back once in a while to finish the last questions
#
# ❓ **Question** ❓ Now, let's plot the previous and current run histories. What do you think of the data augmentation?

# %%
# YOUR CODE HERE
plot_history(history, title='', axs=None, exp_name="")
plot_history(history_aug, title='', axs=None, exp_name="")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f3d74f8edf0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3d74fbd490>)

# %% [markdown]
# 💡 Data augmentation may not improve your performance easily. It strongly depends on the model architecture you used, the learning rate, the type of augmentation chosen, etc...Image classification is an art that takes lots of practice to master!
#
# 🚨 **Don't spend too much time now trying to finetune your model - you have other interesting challenge ahead**.
#
# 📚 [here is a good example of solution for future reference](https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/). They manage to get about 80% accuracy

# %% [markdown]
# ### 🏁 Congratulation 🏁
